# %%
import pandas as pd
import numpy as np
import json

# %%
df=pd.read_csv('../public/data/colect.csv')
## update順
df = df.sort_values('updateDate', ascending=False)
# indexの振り直し
df = df.reset_index()
df = df.drop(['index'],axis=1)
## nullは""に置換
df = df.fillna("")
## json用のリストを作成
json_list=[]
for index, row in df.iterrows():
    json_item = {
        "title" : row["title"],
        "description" : row["description"],
        "link" : row["link"],
        "imageUrl" : row["imageUrl"],
        "createDate" : row["createDate"],
        "updateDate" : row["updateDate"],
    }
    json_list.append(json_item)
## jsonファイルに書き換える
with open('../public/data/colect.json', 'w') as f:
    json.dump(json_list, f,ensure_ascii=False, indent=4)
df
# Out:
#       title                description       link  \
# 0  sample05                   論文式のデザイン  /sample05
# 1  sample04            Iframeを使用したサンプル  /sample04
# 2  sample03               UIデザインのサンプル。  /sample03
# 3  sample02             アイテムのデザインサンプル。  /sample02
# 4  sample01  画像、youtube動画の一覧を表示するデザイン。  /sample01
#
#                                             imageUrl createDate updateDate
# 0                                   /preparatImg.png   24/10/10   24/10/10
# 1                                   /preparatImg.png   24/09/21   24/09/21
# 2                                   /preparatImg.png   24/09/14   24/09/14
# 3  https://i.gyazo.com/505fc3f175597de655ce21fb4d...   24/09/07   24/09/07
# 4  https://i.gyazo.com/f8bf59f059fe478e8ff969dc2c...   24/09/01   24/09/01
